# %%
import pandas as pd

df= pd.read_csv('datos1.csv')
df_filtrado = df[df['NVNumero'] == 14036]

df_filtrado
# Out:
# Empty DataFrame
# Columns: [NVNumero, nvEstado, fecha_nv, fecha_entrega, ConcAuto, CodProd, nvCant, cant_fact, dif_fact, nvPrecio, DetProd, NomAux, codProc, PROCESO, DescProc, tiempo, CantProd]
# Index: []

# %%
4
